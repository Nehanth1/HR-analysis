# %%
#importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno

# %%
# reading datafile
df_1 = pd.read_excel("E:\capestone project\HRAnalytics\HR Analytics\staff utlz latest 16-17_masked.xlsx")
df_2 = pd.read_excel("E:\capestone project\HRAnalytics\HR Analytics\staff utlz latest 17-18_masked.xlsx")

# %%
df_1.head()
# Out:
#     Unnamed: 0     Unnamed: 1         Unnamed: 2         Unnamed: 3  \
# 0  Employee No  Profit Center      Employee Name  Employee Position
# 1            1         PC - 1   Rochette Jilleen            Level 2
# 2            2         PC - 2     Daryl Natalina            Level 2
# 3            3         PC - 2  Annnora Gabrielle            Level 2
# 4            4         PC - 3        Barbee Joey            Level 2
#
#           Unnamed: 4            Unnamed: 5         Unnamed: 6  \
# 0  Employee Location          People Group  Employee Category
# 1         Location 3  Client Service Staff          Level 1/2
# 2         Location 7  Client Service Staff          Level 1/2
# 3         Location 7  Client Service Staff          Level 1/2
# 4         Location 1  Client Service Staff          Level 1/2
#
#          Unnamed: 7           Unnamed: 8      Unnamed: 9  ... Mar 2017.6  \
# 0   Supervisor name            Join Date  Current Status  ...   NC Hours
# 1  Idalina Lauraine  2000-09-30 00:00:00          Active  ...         24
# 2  Idalina Lauraine  1999-05-31 00:00:00          Active  ...        1.5
# 3  Idalina Lauraine  2001-01-31 00:00:00          Active  ...         14
# 4  Idalina Lauraine  2000-09-30 00:00:00          Active  ...         16
#
#      Mar 2017.7        Total                Total.1     Total.2      Total.3  \
# 0  Utilization%  Total Hours  Total Available Hours  Work Hours  Leave Hours
# 1      0.525714         2088                   1802         636          216
# 2      0.991848         2088                   1882       555.5          156
# 3      1.264368         2088                 1898.5      1004.5          144
# 4      0.301136         2088                   1851         273          208
#
#           Total.4   Total.5   Total.6       Total.7
# 0  Training Hours  BD Hours  NC Hours  Utilization%
# 1              70      1192        56      0.352941
# 2              50       694       734      0.295165
# 3            45.5       507     549.5      0.529102
# 4              29      1382       255      0.147488
#
# [5 rows x 115 columns]

# %%
df_2.head()
# Out:
#     Unnamed: 0     Unnamed: 1         Unnamed: 2         Unnamed: 3  \
# 0  Employee No  Profit Center      Employee Name  Employee Position
# 1            1         PC - 1   Rochette Jilleen            Level 1
# 2            2         PC - 2     Daryl Natalina            Level 2
# 3            3         PC - 2  Annnora Gabrielle            Level 2
# 4            4         PC - 3        Barbee Joey            Level 2
#
#           Unnamed: 4            Unnamed: 5         Unnamed: 6  \
# 0  Employee Location          People Group  Employee Category
# 1         Location 3  Client Service Staff             SVP/VP
# 2         Location 7  Client Service Staff             SVP/VP
# 3         Location 7  Client Service Staff             SVP/VP
# 4         Location 1  Client Service Staff           Resigned
#
#          Unnamed: 7           Unnamed: 8      Unnamed: 9  ...  \
# 0   Supervisor name            Join Date  Current Status  ...
# 1  Idalina Lauraine  2000-09-30 00:00:00          Active  ...
# 2  Idalina Lauraine  1999-05-31 00:00:00          Active  ...
# 3  Idalina Lauraine  2001-01-31 00:00:00          Active  ...
# 4  Idalina Lauraine  2000-09-30 00:00:00        Resigned  ...
#
#   2018-03-01 00:00:00.6 2018-03-01 00:00:00.7        Total  \
# 0              NC Hours          Utilization%  Total Hours
# 1                     0               0.18125         2080
# 2                  56.5              0.259375         2080
# 3                   -12              1.267857         2080
# 4                     -                     -         1840
#
#                  Total.1     Total.2      Total.3         Total.4   Total.5  \
# 0  Total Available Hours  Work Hours  Leave Hours  Training Hours  BD Hours
# 1                 1864.5         448          188            27.5    1431.5
# 2                   1868         722          208               4     600.5
# 3                   1720        1173          338              22     463.5
# 4                 1640.5         273          196             3.5      1361
#
#     Total.6       Total.7
# 0  NC Hours  Utilization%
# 1        18      0.240279
# 2     596.5       0.38651
# 3     357.5      0.681977
# 4        24      0.166413
#
# [5 rows x 115 columns]

# %%
# resetting header
df_1.columns = df_1.iloc[0]
df_2.columns = df_2.iloc[0]

# %%
df_1.head()
# Out:
# 0  Employee No  Profit Center      Employee Name  Employee Position  \
# 0  Employee No  Profit Center      Employee Name  Employee Position
# 1            1         PC - 1   Rochette Jilleen            Level 2
# 2            2         PC - 2     Daryl Natalina            Level 2
# 3            3         PC - 2  Annnora Gabrielle            Level 2
# 4            4         PC - 3        Barbee Joey            Level 2
#
# 0  Employee Location          People Group  Employee Category  \
# 0  Employee Location          People Group  Employee Category
# 1         Location 3  Client Service Staff          Level 1/2
# 2         Location 7  Client Service Staff          Level 1/2
# 3         Location 7  Client Service Staff          Level 1/2
# 4         Location 1  Client Service Staff          Level 1/2
#
# 0   Supervisor name            Join Date  Current Status  ...  NC Hours  \
# 0   Supervisor name            Join Date  Current Status  ...  NC Hours
# 1  Idalina Lauraine  2000-09-30 00:00:00          Active  ...        24
# 2  Idalina Lauraine  1999-05-31 00:00:00          Active  ...       1.5
# 3  Idalina Lauraine  2001-01-31 00:00:00          Active  ...        14
# 4  Idalina Lauraine  2000-09-30 00:00:00          Active  ...        16
#
# 0  Utilization%  Total Hours  Total Available Hours  Work Hours  Leave Hours  \
# 0  Utilization%  Total Hours  Total Available Hours  Work Hours  Leave Hours
# 1      0.525714         2088                   1802         636          216
# 2      0.991848         2088                   1882       555.5          156
# 3      1.264368         2088                 1898.5      1004.5          144
# 4      0.301136         2088                   1851         273          208
#
# 0  Training Hours  BD Hours  NC Hours  Utilization%
# 0  Training Hours  BD Hours  NC Hours  Utilization%
# 1              70      1192        56      0.352941
# 2              50       694       734      0.295165
# 3            45.5       507     549.5      0.529102
# 4              29      1382       255      0.147488
#
# [5 rows x 115 columns]

# %%
# now we remove the row.
df_1 = df_1.drop(0)
df_2 = df_2.drop(0)

# %%
df_1.head()
# Out:
# 0 Employee No Profit Center      Employee Name Employee Position  \
# 1           1        PC - 1   Rochette Jilleen           Level 2
# 2           2        PC - 2     Daryl Natalina           Level 2
# 3           3        PC - 2  Annnora Gabrielle           Level 2
# 4           4        PC - 3        Barbee Joey           Level 2
# 5           5        PC - 4   Idalina Lauraine           Level 1
#
# 0 Employee Location          People Group Employee Category   Supervisor name  \
# 1        Location 3  Client Service Staff         Level 1/2  Idalina Lauraine
# 2        Location 7  Client Service Staff         Level 1/2  Idalina Lauraine
# 3        Location 7  Client Service Staff         Level 1/2  Idalina Lauraine
# 4        Location 1  Client Service Staff         Level 1/2  Idalina Lauraine
# 5        Location 3  Client Service Staff         Level 1/2     Abagail Druci
#
# 0            Join Date Current Status  ... NC Hours Utilization% Total Hours  \
# 1  2000-09-30 00:00:00         Active  ...       24     0.525714        2088
# 2  1999-05-31 00:00:00         Active  ...      1.5     0.991848        2088
# 3  2001-01-31 00:00:00         Active  ...       14     1.264368        2088
# 4  2000-09-30 00:00:00         Active  ...       16     0.301136        2088
# 5  1998-06-30 00:00:00         Active  ...        -            -        1312
#
# 0 Total Available Hours Work Hours Leave Hours Training Hours BD Hours  \
# 1                  1802        636         216             70     1192
# 2                  1882      555.5         156             50      694
# 3                1898.5     1004.5         144           45.5      507
# 4                  1851        273         208             29     1382
# 5                  1205        149         104              3     1159
#
# 0 NC Hours Utilization%
# 1       56     0.352941
# 2      734     0.295165
# 3    549.5     0.529102
# 4      255     0.147488
# 5      818     0.123651
#
# [5 rows x 115 columns]

# %%
#setting index from Employee No
df_1 = df_1.set_index('Employee No')
df_2 = df_2.set_index('Employee No')

# %%
df_2.head()
# Out:
# 0           Profit Center      Employee Name Employee Position  \
# Employee No
# 1                  PC - 1   Rochette Jilleen           Level 1
# 2                  PC - 2     Daryl Natalina           Level 2
# 3                  PC - 2  Annnora Gabrielle           Level 2
# 4                  PC - 3        Barbee Joey           Level 2
# 6                  PC - 1     Jordanna Danya           Level 2
#
# 0           Employee Location          People Group Employee Category  \
# Employee No
# 1                  Location 3  Client Service Staff            SVP/VP
# 2                  Location 7  Client Service Staff            SVP/VP
# 3                  Location 7  Client Service Staff            SVP/VP
# 4                  Location 1  Client Service Staff          Resigned
# 6                  Location 3  Client Service Staff            SVP/VP
#
# 0             Supervisor name            Join Date Current Status  \
# Employee No
# 1            Idalina Lauraine  2000-09-30 00:00:00         Active
# 2            Idalina Lauraine  1999-05-31 00:00:00         Active
# 3            Idalina Lauraine  2001-01-31 00:00:00         Active
# 4            Idalina Lauraine  2000-09-30 00:00:00       Resigned
# 6            Idalina Lauraine  2002-06-30 00:00:00         Active
#
# 0               Termination Date  ... NC Hours Utilization% Total Hours  \
# Employee No                       ...
# 1                            NaN  ...        0      0.18125        2080
# 2                            NaN  ...     56.5     0.259375        2080
# 3                            NaN  ...      -12     1.267857        2080
# 4            2018-02-28 00:00:00  ...        -            -        1840
# 6                            NaN  ...       32     0.233333        2080
#
# 0           Total Available Hours Work Hours Leave Hours Training Hours  \
# Employee No
# 1                          1864.5        448         188           27.5
# 2                            1868        722         208              4
# 3                            1720       1173         338             22
# 4                          1640.5        273         196            3.5
# 6                            1812        428         260              8
#
# 0           BD Hours NC Hours Utilization%
# Employee No
# 1             1431.5       18     0.240279
# 2              600.5    596.5      0.38651
# 3              463.5    357.5     0.681977
# 4               1361       24     0.166413
# 6               1237      470     0.236203
#
# [5 rows x 114 columns]

# %%
#saving the file
file_name="E:\capestone project\HRAnalytics\HR Analytics\2016.xlsx"
df_1.to_csv(file_name,sep=',',encoding='utf-8')
file_name="E:\capestone project\HRAnalytics\HR Analytics\2018.xlsx"
df_2.to_csv(file_name,sep=',',encoding='utf-8')

# %%
df_1 = pd.read_csv("E:\capestone project\HRAnalytics\HR Analytics\2016.xlsx")
df_2 = pd.read_csv("E:\capestone project\HRAnalytics\HR Analytics\2018.xlsx")

# %%
df_1.head()
# Out:
#    Employee No Profit Center      Employee Name Employee Position  \
# 0            1        PC - 1   Rochette Jilleen           Level 2
# 1            2        PC - 2     Daryl Natalina           Level 2
# 2            3        PC - 2  Annnora Gabrielle           Level 2
# 3            4        PC - 3        Barbee Joey           Level 2
# 4            5        PC - 4   Idalina Lauraine           Level 1
#
#   Employee Location          People Group Employee Category   Supervisor name  \
# 0        Location 3  Client Service Staff         Level 1/2  Idalina Lauraine
# 1        Location 7  Client Service Staff         Level 1/2  Idalina Lauraine
# 2        Location 7  Client Service Staff         Level 1/2  Idalina Lauraine
# 3        Location 1  Client Service Staff         Level 1/2  Idalina Lauraine
# 4        Location 3  Client Service Staff         Level 1/2     Abagail Druci
#
#              Join Date Current Status  ... NC Hours.11      Utilization%.11  \
# 0  2000-09-30 00:00:00         Active  ...          24   0.5257142857142857
# 1  1999-05-31 00:00:00         Active  ...         1.5   0.9918478260869565
# 2  2001-01-31 00:00:00         Active  ...          14    1.264367816091954
# 3  2000-09-30 00:00:00         Active  ...          16  0.30113636363636365
# 4  1998-06-30 00:00:00         Active  ...           -                    -
#
#   Total Hours.12 Total Available Hours.12 Work Hours.12 Leave Hours.12  \
# 0           2088                   1802.0         636.0          216.0
# 1           2088                   1882.0         555.5          156.0
# 2           2088                   1898.5        1004.5          144.0
# 3           2088                   1851.0         273.0          208.0
# 4           1312                   1205.0         149.0          104.0
#
#   Training Hours.12 BD Hours.12 NC Hours.12      Utilization%.12
# 0              70.0      1192.0        56.0  0.35294117647058826
# 1              50.0       694.0       734.0  0.29516471838469716
# 2              45.5       507.0       549.5   0.5291019225704503
# 3              29.0      1382.0       255.0  0.14748784440842788
# 4               3.0      1159.0       818.0  0.12365145228215768
#
# [5 rows x 115 columns]

# %%
df_1.shape
# Out:
# (789, 115)

# %%
df_2.shape
# Out:
# (973, 115)

# %%
# combine botht the data files.
df = pd.concat([df_1,df_2]).reset_index(drop=True)

# %%
df.head()
# Out:
#    Employee No Profit Center      Employee Name Employee Position  \
# 0            1        PC - 1   Rochette Jilleen           Level 2
# 1            2        PC - 2     Daryl Natalina           Level 2
# 2            3        PC - 2  Annnora Gabrielle           Level 2
# 3            4        PC - 3        Barbee Joey           Level 2
# 4            5        PC - 4   Idalina Lauraine           Level 1
#
#   Employee Location          People Group Employee Category   Supervisor name  \
# 0        Location 3  Client Service Staff         Level 1/2  Idalina Lauraine
# 1        Location 7  Client Service Staff         Level 1/2  Idalina Lauraine
# 2        Location 7  Client Service Staff         Level 1/2  Idalina Lauraine
# 3        Location 1  Client Service Staff         Level 1/2  Idalina Lauraine
# 4        Location 3  Client Service Staff         Level 1/2     Abagail Druci
#
#              Join Date Current Status  ... NC Hours.11      Utilization%.11  \
# 0  2000-09-30 00:00:00         Active  ...          24   0.5257142857142857
# 1  1999-05-31 00:00:00         Active  ...         1.5   0.9918478260869565
# 2  2001-01-31 00:00:00         Active  ...          14    1.264367816091954
# 3  2000-09-30 00:00:00         Active  ...          16  0.30113636363636365
# 4  1998-06-30 00:00:00         Active  ...           -                    -
#
#   Total Hours.12 Total Available Hours.12 Work Hours.12 Leave Hours.12  \
# 0           2088                   1802.0         636.0          216.0
# 1           2088                   1882.0         555.5          156.0
# 2           2088                   1898.5        1004.5          144.0
# 3           2088                   1851.0         273.0          208.0
# 4           1312                   1205.0         149.0          104.0
#
#   Training Hours.12 BD Hours.12 NC Hours.12      Utilization%.12
# 0              70.0      1192.0        56.0  0.35294117647058826
# 1              50.0       694.0       734.0  0.29516471838469716
# 2              45.5       507.0       549.5   0.5291019225704503
# 3              29.0      1382.0       255.0  0.14748784440842788
# 4               3.0      1159.0       818.0  0.12365145228215768
#
# [5 rows x 115 columns]

# %%
df.shape
# Out:
# (1762, 115)

# %%
#drop duplicates

df = df.drop_duplicates(subset='Employee No')

# %%
df = df.drop_duplicates(subset='Employee Name')

# %%
df.shape
# Out:
# (1106, 115)

# %%
# removing columns which are not necessary for this dataset
df=df.drop(df.columns[11:107], axis=1)

# %%
df.head()
# Out:
#    Employee No Profit Center      Employee Name Employee Position  \
# 0            1        PC - 1   Rochette Jilleen           Level 2
# 1            2        PC - 2     Daryl Natalina           Level 2
# 2            3        PC - 2  Annnora Gabrielle           Level 2
# 3            4        PC - 3        Barbee Joey           Level 2
# 4            5        PC - 4   Idalina Lauraine           Level 1
#
#   Employee Location          People Group Employee Category   Supervisor name  \
# 0        Location 3  Client Service Staff         Level 1/2  Idalina Lauraine
# 1        Location 7  Client Service Staff         Level 1/2  Idalina Lauraine
# 2        Location 7  Client Service Staff         Level 1/2  Idalina Lauraine
# 3        Location 1  Client Service Staff         Level 1/2  Idalina Lauraine
# 4        Location 3  Client Service Staff         Level 1/2     Abagail Druci
#
#              Join Date Current Status Termination Date  Total Hours.12  \
# 0  2000-09-30 00:00:00         Active                -            2088
# 1  1999-05-31 00:00:00         Active                -            2088
# 2  2001-01-31 00:00:00         Active                -            2088
# 3  2000-09-30 00:00:00         Active                -            2088
# 4  1998-06-30 00:00:00         Active                -            1312
#
#    Total Available Hours.12  Work Hours.12  Leave Hours.12  Training Hours.12  \
# 0                    1802.0          636.0           216.0               70.0
# 1                    1882.0          555.5           156.0               50.0
# 2                    1898.5         1004.5           144.0               45.5
# 3                    1851.0          273.0           208.0               29.0
# 4                    1205.0          149.0           104.0                3.0
#
#    BD Hours.12  NC Hours.12      Utilization%.12
# 0       1192.0         56.0  0.35294117647058826
# 1        694.0        734.0  0.29516471838469716
# 2        507.0        549.5   0.5291019225704503
# 3       1382.0        255.0  0.14748784440842788
# 4       1159.0        818.0  0.12365145228215768

# %%
#check the types of columns
df.dtypes
# Out:
# Employee No                   int64
# Profit Center                object
# Employee Name                object
# Employee Position            object
# Employee Location            object
# People Group                 object
# Employee Category            object
# Supervisor name              object
# Join Date                    object
# Current Status               object
# Termination Date             object
# Total Hours.12                int64
# Total Available Hours.12    float64
# Work Hours.12               float64
# Leave Hours.12              float64
# Training Hours.12           float64
# BD Hours.12                 float64
# NC Hours.12                 float64
# Utilization%.12              object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1106 entries, 0 to 1761
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Employee No               1106 non-null   int64
#  1   Profit Center             1106 non-null   object
#  2   Employee Name             1106 non-null   object
#  3   Employee Position         1106 non-null   object
#  4   Employee Location         1106 non-null   object
#  5   People Group              1106 non-null   object
#  6   Employee Category         1106 non-null   object
#  7   Supervisor name           1106 non-null   object
#  8   Join Date                 1106 non-null   object
#  9   Current Status            1106 non-null   object
#  10  Termination Date          819 non-null    object
#  11  Total Hours.12            1106 non-null   int64
#  12  Total Available Hours.12  1106 non-null   float64
#  13  Work Hours.12             1106 non-null   float64
#  14  Leave Hours.12            1106 non-null   float64
#  15  Training Hours.12         1106 non-null   float64
#  16  BD Hours.12               1106 non-null   float64
#  17  NC Hours.12               1106 non-null   float64
#  18  Utilization%.12           1106 non-null   object
# dtypes: float64(6), int64(2), object(11)
# memory usage: 172.8+ KB

# %%
#check for missing values"
df.isna().sum()
# Out:
# Employee No                   0
# Profit Center                 0
# Employee Name                 0
# Employee Position             0
# Employee Location             0
# People Group                  0
# Employee Category             0
# Supervisor name               0
# Join Date                     0
# Current Status                0
# Termination Date            287
# Total Hours.12                0
# Total Available Hours.12      0
# Work Hours.12                 0
# Leave Hours.12                0
# Training Hours.12             0
# BD Hours.12                   0
# NC Hours.12                   0
# Utilization%.12               0
# dtype: int64

# %%
msno.matrix(df)
# Out:
# <AxesSubplot:>

# %%
msno.bar(df, color='b', figsize = (7,7))
# Out:
# <AxesSubplot:>

# %%
# setting employee No as index
df=df.set_index('Employee No')

# %%
#unique values
# we can see that below few columns have categorical variables, we will do label encodeing.
{column: len(df[column].unique()) for column in df.columns}
# Out:
# {'Profit Center': 10,
#  'Employee Name': 1106,
#  'Employee Position': 13,
#  'Employee Location': 9,
#  'People Group': 2,
#  'Employee Category': 9,
#  'Supervisor name': 150,
#  'Join Date': 127,
#  'Current Status': 4,
#  'Termination Date': 27,
#  'Total Hours.12': 149,
#  'Total Available Hours.12': 807,
#  'Work Hours.12': 767,
#  'Leave Hours.12': 127,
#  'Training Hours.12': 252,
#  'BD Hours.12': 126,
#  'NC Hours.12': 673,
#  'Utilization%.12': 1008}

# %%
# we can remove join date and termination date, as the current status is there.
df=df.drop(df.columns[7], axis=1)

# %%
# we can remove join date and termination date, as the current status is there.
df=df.drop(df.columns[8], axis=1)
df.head()
# Out:
#             Profit Center      Employee Name Employee Position  \
# Employee No
# 1                  PC - 1   Rochette Jilleen           Level 2
# 2                  PC - 2     Daryl Natalina           Level 2
# 3                  PC - 2  Annnora Gabrielle           Level 2
# 4                  PC - 3        Barbee Joey           Level 2
# 5                  PC - 4   Idalina Lauraine           Level 1
#
#             Employee Location          People Group Employee Category  \
# Employee No
# 1                  Location 3  Client Service Staff         Level 1/2
# 2                  Location 7  Client Service Staff         Level 1/2
# 3                  Location 7  Client Service Staff         Level 1/2
# 4                  Location 1  Client Service Staff         Level 1/2
# 5                  Location 3  Client Service Staff         Level 1/2
#
#               Supervisor name Current Status  Total Hours.12  \
# Employee No
# 1            Idalina Lauraine         Active            2088
# 2            Idalina Lauraine         Active            2088
# 3            Idalina Lauraine         Active            2088
# 4            Idalina Lauraine         Active            2088
# 5               Abagail Druci         Active            1312
#
#              Total Available Hours.12  Work Hours.12  Leave Hours.12  \
# Employee No
# 1                              1802.0          636.0           216.0
# 2                              1882.0          555.5           156.0
# 3                              1898.5         1004.5           144.0
# 4                              1851.0          273.0           208.0
# 5                              1205.0          149.0           104.0
#
#              Training Hours.12  BD Hours.12  NC Hours.12      Utilization%.12
# Employee No
# 1                         70.0       1192.0         56.0  0.35294117647058826
# 2                         50.0        694.0        734.0  0.29516471838469716
# 3                         45.5        507.0        549.5   0.5291019225704503
# 4                         29.0       1382.0        255.0  0.14748784440842788
# 5                          3.0       1159.0        818.0  0.12365145228215768

# %%
# converted utilization column from object dtype to float data type
df['Utilization%.12'] = pd.to_numeric(df['Utilization%.12'],errors='coerce')

# %%
#label encoding categorical variables.
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
df['Profit Center'] = labelencoder.fit_transform(df['Profit Center'])
df['Employee Location'] = labelencoder.fit_transform(df['Employee Location'])
df.head()
# Out:
#              Profit Center      Employee Name Employee Position  \
# Employee No
# 1                        0   Rochette Jilleen           Level 2
# 2                        2     Daryl Natalina           Level 2
# 3                        2  Annnora Gabrielle           Level 2
# 4                        3        Barbee Joey           Level 2
# 5                        4   Idalina Lauraine           Level 1
#
#              Employee Location          People Group Employee Category  \
# Employee No
# 1                            2  Client Service Staff         Level 1/2
# 2                            6  Client Service Staff         Level 1/2
# 3                            6  Client Service Staff         Level 1/2
# 4                            0  Client Service Staff         Level 1/2
# 5                            2  Client Service Staff         Level 1/2
#
#               Supervisor name Current Status  Total Hours.12  \
# Employee No
# 1            Idalina Lauraine         Active            2088
# 2            Idalina Lauraine         Active            2088
# 3            Idalina Lauraine         Active            2088
# 4            Idalina Lauraine         Active            2088
# 5               Abagail Druci         Active            1312
#
#              Total Available Hours.12  Work Hours.12  Leave Hours.12  \
# Employee No
# 1                              1802.0          636.0           216.0
# 2                              1882.0          555.5           156.0
# 3                              1898.5         1004.5           144.0
# 4                              1851.0          273.0           208.0
# 5                              1205.0          149.0           104.0
#
#              Training Hours.12  BD Hours.12  NC Hours.12  Utilization%.12
# Employee No
# 1                         70.0       1192.0         56.0         0.352941
# 2                         50.0        694.0        734.0         0.295165
# 3                         45.5        507.0        549.5         0.529102
# 4                         29.0       1382.0        255.0         0.147488
# 5                          3.0       1159.0        818.0         0.123651

# %%
# current status has 4 categories, where 2 categories comes under active. hence, we can do it as 0 and 1
df['Current Status']=df['Current Status'].replace({'Active':0,'Secondment':0,'Sabbatical':0,'New Joiner':0,'Resigned':1})

# %%
# converting employee position to numerical categories
df['Employee Position']=df['Employee Position'].replace({'Level 1':1,'Level A1':1,'Level 2':2,'Level A2':2,'Level 3':3,
                                                         'Level A3':3,'Level 4':4,'Level 5':5,'Level 6':6,'Level 7':7,'Level 8':8,
                                                         'Level 10':10,'-':0
                                                        })

# %%
df['People Group'].value_counts()
# Out:
# Client Service Staff    1096
# Support Staff             10
# Name: People Group, dtype: int64

# %%
# get dummies for people group, concat the columns and drop the column people group
people = pd.get_dummies(df['People Group'])
df = pd.concat((df, people), axis = 1)
df.head()
# Out:
#              Profit Center      Employee Name  Employee Position  \
# Employee No
# 1                        0   Rochette Jilleen                  2
# 2                        2     Daryl Natalina                  2
# 3                        2  Annnora Gabrielle                  2
# 4                        3        Barbee Joey                  2
# 5                        4   Idalina Lauraine                  1
#
#              Employee Location          People Group Employee Category  \
# Employee No
# 1                            2  Client Service Staff         Level 1/2
# 2                            6  Client Service Staff         Level 1/2
# 3                            6  Client Service Staff         Level 1/2
# 4                            0  Client Service Staff         Level 1/2
# 5                            2  Client Service Staff         Level 1/2
#
#               Supervisor name  Current Status  Total Hours.12  \
# Employee No
# 1            Idalina Lauraine               0            2088
# 2            Idalina Lauraine               0            2088
# 3            Idalina Lauraine               0            2088
# 4            Idalina Lauraine               0            2088
# 5               Abagail Druci               0            1312
#
#              Total Available Hours.12  Work Hours.12  Leave Hours.12  \
# Employee No
# 1                              1802.0          636.0           216.0
# 2                              1882.0          555.5           156.0
# 3                              1898.5         1004.5           144.0
# 4                              1851.0          273.0           208.0
# 5                              1205.0          149.0           104.0
#
#              Training Hours.12  BD Hours.12  NC Hours.12  Utilization%.12  \
# Employee No
# 1                         70.0       1192.0         56.0         0.352941
# 2                         50.0        694.0        734.0         0.295165
# 3                         45.5        507.0        549.5         0.529102
# 4                         29.0       1382.0        255.0         0.147488
# 5                          3.0       1159.0        818.0         0.123651
#
#              Client Service Staff  Support Staff
# Employee No
# 1                               1              0
# 2                               1              0
# 3                               1              0
# 4                               1              0
# 5                               1              0

# %%
# additionally supervisor name can be dropped.
df = df.drop(df.columns[6], axis=1)
df.head()
# Out:
#              Profit Center      Employee Name  Employee Position  \
# Employee No
# 1                        0   Rochette Jilleen                  2
# 2                        2     Daryl Natalina                  2
# 3                        2  Annnora Gabrielle                  2
# 4                        3        Barbee Joey                  2
# 5                        4   Idalina Lauraine                  1
#
#              Employee Location          People Group Employee Category  \
# Employee No
# 1                            2  Client Service Staff         Level 1/2
# 2                            6  Client Service Staff         Level 1/2
# 3                            6  Client Service Staff         Level 1/2
# 4                            0  Client Service Staff         Level 1/2
# 5                            2  Client Service Staff         Level 1/2
#
#              Current Status  Total Hours.12  Total Available Hours.12  \
# Employee No
# 1                         0            2088                    1802.0
# 2                         0            2088                    1882.0
# 3                         0            2088                    1898.5
# 4                         0            2088                    1851.0
# 5                         0            1312                    1205.0
#
#              Work Hours.12  Leave Hours.12  Training Hours.12  BD Hours.12  \
# Employee No
# 1                    636.0           216.0               70.0       1192.0
# 2                    555.5           156.0               50.0        694.0
# 3                   1004.5           144.0               45.5        507.0
# 4                    273.0           208.0               29.0       1382.0
# 5                    149.0           104.0                3.0       1159.0
#
#              NC Hours.12  Utilization%.12  Client Service Staff  Support Staff
# Employee No
# 1                   56.0         0.352941                     1              0
# 2                  734.0         0.295165                     1              0
# 3                  549.5         0.529102                     1              0
# 4                  255.0         0.147488                     1              0
# 5                  818.0         0.123651                     1              0

# %%
#people group also removed.
df = df.drop(df.columns[4], axis=1)
df.head()
# Out:
#              Profit Center      Employee Name  Employee Position  \
# Employee No
# 1                        0   Rochette Jilleen                  2
# 2                        2     Daryl Natalina                  2
# 3                        2  Annnora Gabrielle                  2
# 4                        3        Barbee Joey                  2
# 5                        4   Idalina Lauraine                  1
#
#              Employee Location Employee Category  Current Status  \
# Employee No
# 1                            2         Level 1/2               0
# 2                            6         Level 1/2               0
# 3                            6         Level 1/2               0
# 4                            0         Level 1/2               0
# 5                            2         Level 1/2               0
#
#              Total Hours.12  Total Available Hours.12  Work Hours.12  \
# Employee No
# 1                      2088                    1802.0          636.0
# 2                      2088                    1882.0          555.5
# 3                      2088                    1898.5         1004.5
# 4                      2088                    1851.0          273.0
# 5                      1312                    1205.0          149.0
#
#              Leave Hours.12  Training Hours.12  BD Hours.12  NC Hours.12  \
# Employee No
# 1                     216.0               70.0       1192.0         56.0
# 2                     156.0               50.0        694.0        734.0
# 3                     144.0               45.5        507.0        549.5
# 4                     208.0               29.0       1382.0        255.0
# 5                     104.0                3.0       1159.0        818.0
#
#              Utilization%.12  Client Service Staff  Support Staff
# Employee No
# 1                   0.352941                     1              0
# 2                   0.295165                     1              0
# 3                   0.529102                     1              0
# 4                   0.147488                     1              0
# 5                   0.123651                     1              0

# %%
df['Employee Category'].unique()
# Out:
# array(['Level 1/2', 'Confirmed Staff', 'Serving Notice Period',
#        'Secondee-Outward-Without Pay', 'Awaiting Termination',
#        'Staff on Probation', 'Secondee-Outward-With Pay', 'Resigned',
#        'Fixed term Staff'], dtype=object)

# %%
# maping with numeric variables in employee category.
df['Employee Category'] = df['Employee Category'].map({'Confirmed Staff':0,'Level 1/2':1,'Serving Notice Period':2,
                              'Secondee-Outward-Without Pay':3, 'Awaiting Termination':2,
                              'Staff on Probation':1,'Secondee-Outward-With Pay':3,'Resigned':2,'Fixed term Staff':1})

# %%
# assigned confirmed staff as 0, level 1/2, staff on probation and fixed term staff as 1, serving notice,
#awaiting termination and resinged as 2, Secondee-outward-without pay and with pay as 3
df['Employee Category'].value_counts()
# Out:
# 0    735
# 2    201
# 1    165
# 3      5
# Name: Employee Category, dtype: int64

# %%
sns.countplot(df['Employee Category'])
# Out:
# C:\Users\Nehanth\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Employee Category', ylabel='count'>

# %%
sns.countplot(y='Employee Category', hue='Current Status', data=df, palette='magma')
# Out:
# <AxesSubplot:xlabel='count', ylabel='Employee Category'>

# %%
# graphical representation of numeric data distribution among data groups.
df.hist(edgecolor='black', linewidth=1.2, figsize=(15,15))
# Out:
# array([[<AxesSubplot:title={'center':'Profit Center'}>,
#         <AxesSubplot:title={'center':'Employee Position'}>,
#         <AxesSubplot:title={'center':'Employee Location'}>,
#         <AxesSubplot:title={'center':'Employee Category'}>],
#        [<AxesSubplot:title={'center':'Current Status'}>,
#         <AxesSubplot:title={'center':'Total Hours.12'}>,
#         <AxesSubplot:title={'center':'Total Available Hours.12'}>,
#         <AxesSubplot:title={'center':'Work Hours.12'}>],
#        [<AxesSubplot:title={'center':'Leave Hours.12'}>,
#         <AxesSubplot:title={'center':'Training Hours.12'}>,
#         <AxesSubplot:title={'center':'BD Hours.12'}>,
#         <AxesSubplot:title={'center':'NC Hours.12'}>],
#        [<AxesSubplot:title={'center':'Utilization%.12'}>,
#         <AxesSubplot:title={'center':'Client Service Staff'}>,
#         <AxesSubplot:title={'center':'Support Staff'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
dfFilter = df[df['Total Available Hours.12'] > 2000]

dfFilter.loc[:,['Work Hours.12','Total Available Hours.12'] ].plot.bar(stacked=False)
# Out:
# <AxesSubplot:xlabel='Employee No'>

# %%
df['Training Hours.12'].plot(kind='density')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
#finding correlation of data.
df.corr()
# Out:
#                           Profit Center  Employee Position  Employee Location  \
# Profit Center                  1.000000           0.044296          -0.169095
# Employee Position              0.044296           1.000000          -0.030938
# Employee Location             -0.169095          -0.030938           1.000000
# Employee Category              0.053972           0.093279           0.002455
# Current Status                 0.036330           0.057801           0.032227
# Total Hours.12                 0.001822          -0.237492           0.029369
# Total Available Hours.12       0.013516          -0.244784           0.023208
# Work Hours.12                  0.002922           0.095750           0.035756
# Leave Hours.12                -0.015758          -0.129943          -0.011898
# Training Hours.12             -0.140445           0.192398           0.232148
# BD Hours.12                   -0.006852          -0.453824           0.006049
# NC Hours.12                    0.035972          -0.300027          -0.011172
# Utilization%.12               -0.011260           0.249516           0.063241
# Client Service Staff           0.039839           0.273100          -0.001193
# Support Staff                 -0.039839          -0.273100           0.001193
#
#                           Employee Category  Current Status  Total Hours.12  \
# Profit Center                      0.053972        0.036330        0.001822
# Employee Position                  0.093279        0.057801       -0.237492
# Employee Location                  0.002455        0.032227        0.029369
# Employee Category                  1.000000        0.784764       -0.574333
# Current Status                     0.784764        1.000000       -0.330403
# Total Hours.12                    -0.574333       -0.330403        1.000000
# Total Available Hours.12          -0.560399       -0.316908        0.978557
# Work Hours.12                     -0.476663       -0.281308        0.764284
# Leave Hours.12                    -0.286285       -0.169895        0.545327
# Training Hours.12                 -0.221375       -0.203861        0.128946
# BD Hours.12                       -0.065806       -0.061570        0.167202
# NC Hours.12                       -0.159998       -0.059533        0.353913
# Utilization%.12                   -0.192142       -0.088417        0.270527
# Client Service Staff               0.027013        0.040850       -0.047938
# Support Staff                     -0.027013       -0.040850        0.047938
#
#                           Total Available Hours.12  Work Hours.12  \
# Profit Center                             0.013516       0.002922
# Employee Position                        -0.244784       0.095750
# Employee Location                         0.023208       0.035756
# Employee Category                        -0.560399      -0.476663
# Current Status                           -0.316908      -0.281308
# Total Hours.12                            0.978557       0.764284
# Total Available Hours.12                  1.000000       0.777799
# Work Hours.12                             0.777799       1.000000
# Leave Hours.12                            0.367314       0.284826
# Training Hours.12                         0.084883       0.127186
# BD Hours.12                               0.173329      -0.181657
# NC Hours.12                               0.364921      -0.156012
# Utilization%.12                           0.273291       0.660769
# Client Service Staff                     -0.030278       0.149615
# Support Staff                             0.030278      -0.149615
#
#                           Leave Hours.12  Training Hours.12  BD Hours.12  \
# Profit Center                  -0.015758          -0.140445    -0.006852
# Employee Position              -0.129943           0.192398    -0.453824
# Employee Location              -0.011898           0.232148     0.006049
# Employee Category              -0.286285          -0.221375    -0.065806
# Current Status                 -0.169895          -0.203861    -0.061570
# Total Hours.12                  0.545327           0.128946     0.167202
# Total Available Hours.12        0.367314           0.084883     0.173329
# Work Hours.12                   0.284826           0.127186    -0.181657
# Leave Hours.12                  1.000000           0.018233     0.069915
# Training Hours.12               0.018233           1.000000    -0.056509
# BD Hours.12                     0.069915          -0.056509     1.000000
# NC Hours.12                     0.119006           0.034247    -0.035458
# Utilization%.12                 0.093529           0.106797    -0.284865
# Client Service Staff           -0.113659           0.075252     0.023828
# Support Staff                   0.113659          -0.075252    -0.023828
#
#                           NC Hours.12  Utilization%.12  Client Service Staff  \
# Profit Center                0.035972        -0.011260              0.039839
# Employee Position           -0.300027         0.249516              0.273100
# Employee Location           -0.011172         0.063241             -0.001193
# Employee Category           -0.159998        -0.192142              0.027013
# Current Status              -0.059533        -0.088417              0.040850
# Total Hours.12               0.353913         0.270527             -0.047938
# Total Available Hours.12     0.364921         0.273291             -0.030278
# Work Hours.12               -0.156012         0.660769              0.149615
# Leave Hours.12               0.119006         0.093529             -0.113659
# Training Hours.12            0.034247         0.106797              0.075252
# BD Hours.12                 -0.035458        -0.284865              0.023828
# NC Hours.12                  1.000000        -0.417662             -0.323542
# Utilization%.12             -0.417662         1.000000              0.190701
# Client Service Staff        -0.323542         0.190701              1.000000
# Support Staff                0.323542        -0.190701             -1.000000
#
#                           Support Staff
# Profit Center                 -0.039839
# Employee Position             -0.273100
# Employee Location              0.001193
# Employee Category             -0.027013
# Current Status                -0.040850
# Total Hours.12                 0.047938
# Total Available Hours.12       0.030278
# Work Hours.12                 -0.149615
# Leave Hours.12                 0.113659
# Training Hours.12             -0.075252
# BD Hours.12                   -0.023828
# NC Hours.12                    0.323542
# Utilization%.12               -0.190701
# Client Service Staff          -1.000000
# Support Staff                  1.000000

# %%
#graphical representation
plt.figure(figsize=(16,8))
sns.heatmap(df.corr(),annot=True, cmap='Wistia_r',annot_kws={"size":15})
# Out:
# <AxesSubplot:>

# %%
df.describe()
# Out:
#        Profit Center  Employee Position  Employee Location  Employee Category  \
# count    1106.000000        1106.000000        1106.000000        1106.000000
# mean        2.544304           6.690778           2.866184           0.526221
# std         1.785393           1.466441           2.708157           0.800305
# min         0.000000           0.000000           0.000000           0.000000
# 25%         2.000000           6.000000           0.000000           0.000000
# 50%         3.000000           7.000000           2.000000           0.000000
# 75%         3.000000           8.000000           6.000000           1.000000
# max         9.000000          10.000000           8.000000           3.000000
#
#        Current Status  Total Hours.12  Total Available Hours.12  \
# count     1106.000000     1106.000000               1106.000000
# mean         0.154611     1508.289331               1311.967966
# std          0.361697      688.367073                616.322061
# min          0.000000        0.000000                -40.000000
# 25%          0.000000      920.000000                777.625000
# 50%          0.000000     1800.000000               1530.500000
# 75%          0.000000     2088.000000               1832.000000
# max          1.000000     2088.000000               2088.000000
#
#        Work Hours.12  Leave Hours.12  Training Hours.12  BD Hours.12  \
# count    1106.000000     1106.000000        1106.000000  1106.000000
# mean      982.961700      159.567360          36.965579    58.588608
# std       627.843254      148.595004          34.170004   234.970855
# min         0.000000        0.000000         -11.000000   -24.000000
# 25%       432.000000       77.000000          10.000000     0.000000
# 50%      1056.000000      152.000000          27.000000     0.000000
# 75%      1524.750000      208.000000          54.875000     0.000000
# max      2413.000000     1576.000000         169.000000  1876.000000
#
#        NC Hours.12  Utilization%.12  Client Service Staff  Support Staff
# count  1106.000000      1102.000000           1106.000000    1106.000000
# mean    349.642432         0.704328              0.990958       0.009042
# std     353.464835         0.353597              0.094699       0.094699
# min     -28.500000         0.000000              0.000000       0.000000
# 25%      88.250000         0.517149              1.000000       0.000000
# 50%     250.000000         0.807199              1.000000       0.000000
# 75%     479.500000         0.939437              1.000000       0.000000
# max    2458.500000         6.000000              1.000000       1.000000

# %%
#recheck columns for which we can use labelencode or onehot encodder.
for column in df.columns:
    if df[column].dtype == object:
        print(str(column) + ' : '+ str(df[column].unique()))
        print(df[column].value_counts())
        print('**************************************')
# Out:
# Employee Name : ['Rochette Jilleen' 'Daryl Natalina' 'Annnora Gabrielle' ...
#  'Caiden Romero' 'Andy Mejia' 'Alondra Pugh']
# Dominic Kopczynski    1
# Wynn Sandra           1
# Eadie Kiri            1
# Cruz Tucker           1
# Kynthia Hildy         1
#                      ..
# Olia Janeen           1
# Reginald Dennis       1
# Linda Meadows         1
# Caylee Maxwell        1
# Bamby Zahara          1
# Name: Employee Name, Length: 1106, dtype: int64
# **************************************
